# %% [markdown]
# <a href="https://colab.research.google.com/github/Georg-geekbrains/PythonA/blob/main/SemGraf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
import seaborn as sns

# %%
sns.scatterplot(data = df, x = 'households', y = 'population')
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
sns.relplot(data = df, x = 'longitude', y = 'median_house_value', kind = 'line')

# %%
sns.histplot(data = df, x = 'housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
sns.histplot(data = df, x = 'median_house_value', hue = 'housing_median_age')
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %%
df_p = sns.load_dataset('penguins')

# %%
df_p.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.scatterplot(data = df_p, x = 'bill_length_mm', y = 'bill_depth_mm', hue ='sex', size = 5)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data = df_p, x = 'body_mass_g', y = 'flipper_length_mm', hue ='sex', size = 5)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.scatterplot(data = df_p, x = 'bill_depth_mm', y = 'bill_length_mm', hue ='body_mass_g', size = 7)
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %%
list1 = ['bill_length_mm', 'bill_depth_mm','flipper_length_mm', 'body_mass_g', 'sex']
g = sns.PairGrid(df_p[list1])
g.map(sns.scatterplot)

# %%
sns.histplot(data = df_p, x = 'bill_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(data = df_p, x = 'flipper_length_mm')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %% [markdown]
# Задача N°67.
# Создать новый столбец в таблице с пингвинами, который будет отвечать за показатель длины клюва пингвина. high - длинный (от 42) middle - средний(от 35 до 42) low - маленький(до 35)

# %%
df_p.loc[df_p['bill_length_mm']>= 42, 'height_group'] = 'hignt'
df_p.loc[df_p['bill_length_mm']< 35, 'height_group'] = 'low'
df_p.loc[((df_p['bill_length_mm']>=35) &  (df_p['bill_length_mm']<42)), 'height_group'] = 'medium'

# %%
df_p.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex height_group
# 0       3750.0    Male       medium
# 1       3800.0  Female       medium
# 2       3250.0  Female       medium
# 3          NaN     NaN          NaN
# 4       3450.0  Female       medium

# %% [markdown]
# Задача N°69.
# Изобразить гистограмму по flipper_length_mm с оттенком height group. Сделать анализ

# %%
sns.displot(data = df_p, x = 'flipper_length_mm', hue = 'height_group')

# %%
sns.displot(data = df_p, x = 'body_mass_g', hue = 'height_group')
